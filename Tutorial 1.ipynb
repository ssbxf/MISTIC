# %%
import os
import sys

# ✅ 兼容写法：使用当前工作目录
# 假设你的 Notebook 就在项目根目录下 (即与 src 文件夹同级)
src_path = os.path.join(os.getcwd(), 'src')

if src_path not in sys.path:
    sys.path.append(src_path)

import MISTIC

# %%
INPUT_DIR = os.path.join('data', 'IVH')
OUTPUT_BANKSY_DIR = "./output/banksy_processed"

OUTPUT_FILE = os.path.join('output', 'mistic_result.h5ad')
# Preprocessing
N_TOP_GENES = 5000
# Graph Construction Parameters
SPATIAL_NEIGHBORS = 6  # k for spatial graph
SPATIAL_RADIUS = 150.0  # Radius for spatial graph
# Model Training Parameters
IS_HETEROGENEOUS = True  # Use GCN for output layer if True & dense MNN
NUM_EPOCHS = 500
CONTRASTIVE_WEIGHT = 0.05  # Coefficient for contrastive loss
LEARNING_RATE = 0.001
SEED = 42
print("==========================================")
print("       MISTIC Pipeline Started")
print("==========================================")
# ==========================================
# 2. Load and Preprocess
# ==========================================
print("\n[Step 1/5] Loading and Preprocessing Data...")
# Load .h5ad files and perform normalization
raw_adatas, filenames = MISTIC.load_and_preprocess(INPUT_DIR,n_top_genes=N_TOP_GENES)
# Align genes across all slices (intersection)
aligned_adatas = MISTIC.align_common_genes(raw_adatas)

# ==========================================
# 3. Generate BANKSY Features
# ==========================================
print("\n[Step 2/5] Running BANKSY and Preparing Matrices...")

# Compute Banksy matrices and concatenate original data
# Note: raw_adatas memory is cleared inside this function
adata_concat = MISTIC.get_banksy_results(aligned_adatas,filenames,output_dir = OUTPUT_BANKSY_DIR )
# Out:
# ==========================================
#        MISTIC Pipeline Started
# ==========================================
#
# [Step 1/5] Loading and Preprocessing Data...
# Found 4 files. Loading...
# Loaded: 151673
# Loaded: 151674
# Loaded: 151675
# Loaded: 151676
# Number of common genes: 1134
#
# [Step 2/5] Running BANKSY and Preparing Matrices...
# Created output directory: ./output/banksy_processed
# Starting BANKSY computation. Results will be saved to ./output/banksy_processed...
#
# Median distance to closest cell = 137.00364958642524
#
# ---- Ran median_dist_to_nearest_neighbour in 0.01 s ----
#
#
# Median distance to closest cell = 137.0036
#
# ---- Ran generate_spatial_distance_graph in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.13 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.02 s ----
#
# ---- Ran theta_from_spatial_graph in 0.04 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.18 s ----
#
# ----- Plotting theta Graph -----
# Runtime Dec-19-2025-01-21
#
# 1134 genes to be analysed:
# Gene List:
# Index(['AASDHPPT', 'ABCA2', 'ABI1', 'AC004158.1', 'AC005944.1', 'AC008780.2',
#        'AC009133.1', 'AC009812.1', 'AC011603.2', 'AC011603.3',
#        ...
#        'ZNF350-AS1', 'ZNF365', 'ZNF384', 'ZNF385D', 'ZNF536', 'ZNF562',
#        'ZNF585B', 'ZNF844', 'ZNHIT6', 'ZSCAN29'],
#       dtype='object', length=1134)
#
# Check if X contains only finite (non-NAN) values
# Decay Type: scaled_gaussian
# Weights Object: {'weights': {0: <3611x3611 sparse matrix of type '<class 'numpy.float64'>'
# 	with 54165 stored elements in Compressed Sparse Row format>, 1: <3611x3611 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 108330 stored elements in Compressed Sparse Row format>}}
#
# Nbr matrix | Mean: 0.46 | Std: 0.64
# Size of Nbr | Shape: (3611, 1134)
# Top 3 entries of Nbr Mat:
#
# [[0.75429918 0.57112921 0.37889519]
#  [0.18950624 0.05228236 0.79971176]
#  [0.35151011 2.09889008 0.16535594]]
#
# AGF matrix | Mean: 0.09 | Std: 0.08
# Size of AGF mat (m = 1) | Shape: (3611, 1134)
# Top entries of AGF:
# [[0.27201225 0.06703297 0.00745287]
#  [0.07604712 0.05526834 0.13561491]
#  [0.28714188 0.20088206 0.08200072]]
# Ran 'Create BANKSY Matrix' in 0.02 mins
#
# Cell by gene matrix has shape (3611, 1134)
#
# Scale factors squared: [0.8        0.13333333 0.06666667]
# Scale factors: [0.89442719 0.36514837 0.25819889]
# Shape of BANKSY matrix: (3611, 3402)
# Type of banksy_matrix: <class 'anndata._core.anndata.AnnData'>
#
# Saved BANKSY: ./output/banksy_processed/151673_banksy.h5ad
#
# Median distance to closest cell = 137.00364958642524
#
# ---- Ran median_dist_to_nearest_neighbour in 0.01 s ----
#
#
# Median distance to closest cell = 137.0036
#
# ---- Ran generate_spatial_distance_graph in 0.02 s ----
#
# ---- Ran row_normalize in 0.02 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.19 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.03 s ----
#
# ---- Ran theta_from_spatial_graph in 0.05 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.24 s ----
#
# ----- Plotting theta Graph -----
# Runtime Dec-19-2025-01-21
#
# 1134 genes to be analysed:
# Gene List:
# Index(['AASDHPPT', 'ABCA2', 'ABI1', 'AC004158.1', 'AC005944.1', 'AC008780.2',
#        'AC009133.1', 'AC009812.1', 'AC011603.2', 'AC011603.3',
#        ...
#        'ZNF350-AS1', 'ZNF365', 'ZNF384', 'ZNF385D', 'ZNF536', 'ZNF562',
#        'ZNF585B', 'ZNF844', 'ZNHIT6', 'ZSCAN29'],
#       dtype='object', length=1134)
#
# Check if X contains only finite (non-NAN) values
# Decay Type: scaled_gaussian
# Weights Object: {'weights': {0: <3635x3635 sparse matrix of type '<class 'numpy.float64'>'
# 	with 54525 stored elements in Compressed Sparse Row format>, 1: <3635x3635 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 109050 stored elements in Compressed Sparse Row format>}}
#
# Nbr matrix | Mean: 0.49 | Std: 0.64
# Size of Nbr | Shape: (3635, 1134)
# Top 3 entries of Nbr Mat:
#
# [[0.64437831 0.5730138  0.25986363]
#  [0.47430534 0.31067401 0.23563745]
#  [0.092627   1.48300115 0.22463794]]
#
# AGF matrix | Mean: 0.08 | Std: 0.07
# Size of AGF mat (m = 1) | Shape: (3635, 1134)
# Top entries of AGF:
# [[0.1860513  0.15805475 0.05583746]
#  [0.1370651  0.2458174  0.08248015]
#  [0.04300404 0.15450105 0.13211113]]
# Ran 'Create BANKSY Matrix' in 0.02 mins
#
# Cell by gene matrix has shape (3635, 1134)
#
# Scale factors squared: [0.8        0.13333333 0.06666667]
# Scale factors: [0.89442719 0.36514837 0.25819889]
# Shape of BANKSY matrix: (3635, 3402)
# Type of banksy_matrix: <class 'anndata._core.anndata.AnnData'>
#
# Saved BANKSY: ./output/banksy_processed/151674_banksy.h5ad
#
# Median distance to closest cell = 137.00364958642524
#
# ---- Ran median_dist_to_nearest_neighbour in 0.01 s ----
#
#
# Median distance to closest cell = 137.0036
#
# ---- Ran generate_spatial_distance_graph in 0.02 s ----
#
# ---- Ran row_normalize in 0.02 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.18 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.03 s ----
#
# ---- Ran theta_from_spatial_graph in 0.05 s ----
#
# ---- Ran row_normalize in 0.02 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.25 s ----
#
# ----- Plotting theta Graph -----
# Runtime Dec-19-2025-01-21
#
# 1134 genes to be analysed:
# Gene List:
# Index(['AASDHPPT', 'ABCA2', 'ABI1', 'AC004158.1', 'AC005944.1', 'AC008780.2',
#        'AC009133.1', 'AC009812.1', 'AC011603.2', 'AC011603.3',
#        ...
#        'ZNF350-AS1', 'ZNF365', 'ZNF384', 'ZNF385D', 'ZNF536', 'ZNF562',
#        'ZNF585B', 'ZNF844', 'ZNHIT6', 'ZSCAN29'],
#       dtype='object', length=1134)
#
# Check if X contains only finite (non-NAN) values
# Decay Type: scaled_gaussian
# Weights Object: {'weights': {0: <3566x3566 sparse matrix of type '<class 'numpy.float64'>'
# 	with 53490 stored elements in Compressed Sparse Row format>, 1: <3566x3566 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 106980 stored elements in Compressed Sparse Row format>}}
#
# Nbr matrix | Mean: 0.42 | Std: 0.61
# Size of Nbr | Shape: (3566, 1134)
# Top 3 entries of Nbr Mat:
#
# [[0.58880496 0.53643247 0.15859924]
#  [0.57131701 0.63942791 0.33730575]
#  [0.18675753 1.28952847 0.24999718]]
#
# AGF matrix | Mean: 0.09 | Std: 0.08
# Size of AGF mat (m = 1) | Shape: (3566, 1134)
# Top entries of AGF:
# [[0.3202805  0.13513683 0.0757811 ]
#  [0.1076809  0.11664308 0.2138309 ]
#  [0.13784825 0.39205176 0.06820438]]
# Ran 'Create BANKSY Matrix' in 0.02 mins
#
# Cell by gene matrix has shape (3566, 1134)
#
# Scale factors squared: [0.8        0.13333333 0.06666667]
# Scale factors: [0.89442719 0.36514837 0.25819889]
# Shape of BANKSY matrix: (3566, 3402)
# Type of banksy_matrix: <class 'anndata._core.anndata.AnnData'>
#
# Saved BANKSY: ./output/banksy_processed/151675_banksy.h5ad
#
# Median distance to closest cell = 137.00364958642524
#
# ---- Ran median_dist_to_nearest_neighbour in 0.01 s ----
#
#
# Median distance to closest cell = 137.0036
#
# ---- Ran generate_spatial_distance_graph in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.12 s ----
#
# ---- Ran generate_spatial_distance_graph in 0.02 s ----
#
# ---- Ran theta_from_spatial_graph in 0.03 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran generate_spatial_weights_fixed_nbrs in 0.17 s ----
#
# ----- Plotting theta Graph -----
# Runtime Dec-19-2025-01-21
#
# 1134 genes to be analysed:
# Gene List:
# Index(['AASDHPPT', 'ABCA2', 'ABI1', 'AC004158.1', 'AC005944.1', 'AC008780.2',
#        'AC009133.1', 'AC009812.1', 'AC011603.2', 'AC011603.3',
#        ...
#        'ZNF350-AS1', 'ZNF365', 'ZNF384', 'ZNF385D', 'ZNF536', 'ZNF562',
#        'ZNF585B', 'ZNF844', 'ZNHIT6', 'ZSCAN29'],
#       dtype='object', length=1134)
#
# Check if X contains only finite (non-NAN) values
# Decay Type: scaled_gaussian
# Weights Object: {'weights': {0: <3431x3431 sparse matrix of type '<class 'numpy.float64'>'
# 	with 51465 stored elements in Compressed Sparse Row format>, 1: <3431x3431 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 102930 stored elements in Compressed Sparse Row format>}}
#
# Nbr matrix | Mean: 0.44 | Std: 0.62
# Size of Nbr | Shape: (3431, 1134)
# Top 3 entries of Nbr Mat:
#
# [[0.66257916 0.52164128 0.13257153]
#  [0.50821406 0.35916804 0.36870226]
#  [0.17759616 1.6577017  0.3016827 ]]
#
# AGF matrix | Mean: 0.09 | Std: 0.08
# Size of AGF mat (m = 1) | Shape: (3431, 1134)
# Top entries of AGF:
# [[0.06560225 0.11412382 0.07996562]
#  [0.20896094 0.05928678 0.15506953]
#  [0.05429228 0.27011466 0.16436866]]
# Ran 'Create BANKSY Matrix' in 0.02 mins
#
# Cell by gene matrix has shape (3431, 1134)
#
# Scale factors squared: [0.8        0.13333333 0.06666667]
# Scale factors: [0.89442719 0.36514837 0.25819889]
# Shape of BANKSY matrix: (3431, 3402)
# Type of banksy_matrix: <class 'anndata._core.anndata.AnnData'>
#
# Saved BANKSY: ./output/banksy_processed/151676_banksy.h5ad
# Concatenating original data...
# Concatenation complete. Shape: (14243, 1134)
# Cleaning up original batch list memory...

# %%
adata_concat.obs
# Out:
#                       in_tissue  array_row  array_col Ground Truth  \
# 0_AAACAAGTATCTCCCA-1          1         50        102      Layer_3
# 0_AAACAATCTACTAGCA-1          1          3         43      Layer_1
# 0_AAACACCAATAACTGC-1          1         59         19           WM
# 0_AAACAGAGCGACTCCT-1          1         14         94      Layer_3
# 0_AAACAGCTTTCAGAAG-1          1         43          9      Layer_5
# ...                         ...        ...        ...          ...
# 3_TTGTTGTGTGTCAAGA-1          1         31         77      Layer_6
# 3_TTGTTTCACATCCAGG-1          1         58         42           WM
# 3_TTGTTTCATTAGTCTA-1          1         60         30           WM
# 3_TTGTTTCCATACAACT-1          1         45         27      Layer_6
# 3_TTGTTTGTGTAAATTC-1          1          7         51      Layer_1
#
#                      slice_labels slice_name
# 0_AAACAAGTATCTCCCA-1       151673     151673
# 0_AAACAATCTACTAGCA-1       151673     151673
# 0_AAACACCAATAACTGC-1       151673     151673
# 0_AAACAGAGCGACTCCT-1       151673     151673
# 0_AAACAGCTTTCAGAAG-1       151673     151673
# ...                           ...        ...
# 3_TTGTTGTGTGTCAAGA-1       151676     151676
# 3_TTGTTTCACATCCAGG-1       151676     151676
# 3_TTGTTTCATTAGTCTA-1       151676     151676
# 3_TTGTTTCCATACAACT-1       151676     151676
# 3_TTGTTTGTGTAAATTC-1       151676     151676
#
# [14243 rows x 6 columns]

# %%
X_adata, X_expr, X_gra, adj_concat, spatial_adj_concat, avg_mnn = MISTIC.construct_graph(banksy_dir=OUTPUT_BANKSY_DIR)
# Out:
# Loading files from ./output/banksy_processed...
# Processing 151673_banksy.h5ad...
#   --> Average degree: 28.9045
# Processing 151674_banksy.h5ad...
#   --> Average degree: 28.9689
# Processing 151675_banksy.h5ad...
#   --> Average degree: 29.1486
# Processing 151676_banksy.h5ad...
#   --> Average degree: 29.0737
# Concatenating data...
# Constructing block diagonal matrices...
# Computing Cross-Slice MNN...
# MNN Average Degree: 12.1293
# Cleaning up intermediate directory: ./output/banksy_processed
# Cleanup successful.

# %%
IS_HETEROGENEOUS = False
CONTRASTIVE_WEIGHT = 0.5

# %%
print("\n[Step 4/5] Training MISTIC AutoEncoder...")

# Run the training loop
adata_result, model = MISTIC.run_training(
    adata_concat=adata_concat,
    X_adata=X_adata,
    X_expr=X_expr,
    X_gra=X_gra,
    adj_concat=adj_concat,
    spatial_adj_concat=spatial_adj_concat,
    mnn_avg_degree=avg_mnn,
    # Parameters
    is_heterogeneous=IS_HETEROGENEOUS,
    num_epochs=NUM_EPOCHS,
    contrastive_weight=CONTRASTIVE_WEIGHT,
    lr=LEARNING_RATE,
    seed=SEED
)

    # ==========================================
    # 6. Save Results
    # ==========================================
print(f"\n[Step 5/5] Saving results to {OUTPUT_FILE}...")

adata_result.write_h5ad(OUTPUT_FILE)
# Out:
# [Step 4/5] Training MISTIC AutoEncoder...
# Running training on: cuda
# Hyperparameters -> Heterogeneous: False, Epochs: 500, Contrastive Weight: 0.5
# Preparing tensors and graphs...
# Generating contrastive learning pairs...
# Initializing AutoEncoder (Heterogeneous=False, MNN_Avg_Deg=12.13)...
# Starting training for 500 epochs...
# Training MISTIC: 100%|██████████| 500/500 [01:04<00:00,  7.79epoch/s, Con=0.2541, Rec=0.8641, Total_Loss=0.9911]
# Training finished. Extracting embeddings...
# Embedding saved to adata_concat.obsm['MISTIC']
#
# [Step 5/5] Saving results to output/mistic_result.h5ad...

# %%
import scanpy as sc
import matplotlib.pyplot as plt
sc.pp.neighbors(adata_result, use_rep='MISTIC', n_neighbors=15)
sc.tl.umap(adata_result,random_state=42)

def plot_umap(adata_result, color_by, title=None, save_path=None):

    fig, ax = plt.subplots(figsize=(8, 6))

    sc.pl.umap(
        adata_result,
        color=color_by,
        show=False,
        title=title,
        frameon=True,
        ax=ax,
        size=50,
        legend_loc='right margin',
        legend_fontsize=10,
        legend_fontoutline=2
    )


    plt.tight_layout()

    if save_path:

        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    else:

        plt.show()

# slice_labels UMAP
plot_umap(adata_result, color_by=['slice_labels'], title='UMAP colored by Slice Labels')
